# %% [markdown]
# ### In this notebook we will use the raw data to create a simulated different dataset to test datadrift.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("..\\data\\01_raw\\Hotel_H2.csv")
df.tail()
# Out:
#        IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 79325           0        23             2017           August
# 79326           0       102             2017           August
# 79327           0        34             2017           August
# 79328           0       109             2017           August
# 79329           0       205             2017           August
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 79325                     35                     30                     2
# 79326                     35                     31                     2
# 79327                     35                     31                     2
# 79328                     35                     31                     2
# 79329                     35                     29                     2
#
#        StaysInWeekNights  Adults  Children  ...      DepositType        Agent  \
# ...

# %%
data = df[-10000:]

# %%
data.index = [i+10000 for i in data.index]

# %% [markdown]
# We can not mess a lot with dates because it requires a lot of fiddling to get accurate dates according to week number, weekends, etc. So we will stay in 2017. We will change little things in the dataset so we can just test data drift and see how it affects scores. We will see an influx of British people and their ADR will increase.

# %%
data.columns
# Out:
# Index(['IsCanceled', 'LeadTime', 'ArrivalDateYear', 'ArrivalDateMonth',
#        'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth',
#        'StaysInWeekendNights', 'StaysInWeekNights', 'Adults', 'Children',
#        'Babies', 'Meal', 'Country', 'MarketSegment', 'DistributionChannel',
#        'IsRepeatedGuest', 'PreviousCancellations',
#        'PreviousBookingsNotCanceled', 'ReservedRoomType', 'AssignedRoomType',
#        'BookingChanges', 'DepositType', 'Agent', 'Company',
#        'DaysInWaitingList', 'CustomerType', 'ADR', 'RequiredCarParkingSpaces',
#        'TotalOfSpecialRequests', 'ReservationStatus', 'ReservationStatusDate'],
#       dtype='object')

# %%
data
# Out:
#        IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 79330           0       248             2017            April
# 79331           0       248             2017            April
# 79332           0        63             2017            April
# 79333           0        63             2017            April
# 79334           0       248             2017            April
# ...           ...       ...              ...              ...
# 89325           0        23             2017           August
# 89326           0       102             2017           August
# 89327           0        34             2017           August
# 89328           0       109             2017           August
# 89329           0       205             2017           August
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 79330                     15                      9                     2
# ...

# %%
data.loc[data.index[5000:],'Country'] = 'GBR'
data.loc[data.index[5000:],'ADR'] += 50

# %%
len(data.index[5000:])
# Out:
# 5000

# %%
data.IsCanceled.value_counts()
# Out:
# 0    9995
# 1       5
# Name: IsCanceled, dtype: int64

# %% [markdown]
# Let's also pretend they cancel more (75% of the time).

# %%
data.loc[data.index[5000:],'IsCanceled'] = [np.random.choice([0, 1], p=[0.25, 0.75]) for i in range(5000)]

# %%
data.IsCanceled.value_counts()
# Out:
# 0    6296
# 1    3704
# Name: IsCanceled, dtype: int64

# %% [markdown]
# We have to create some specific lines because this is a small dataset and we need certain values to appear for later best columns in feature selection to exist that come from encoding.

# %% [markdown]
# Our fake dataset is created! Let's save it.

# %%
data.to_csv("..\\data\\01_raw\\data_predict.csv")
